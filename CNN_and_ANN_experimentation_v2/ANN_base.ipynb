# %% [markdown]
# # **Worksapce set up**

# %%
# Connecting to google drive
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# Import libraries
# %pylab inline

import tensorflow as tf
import tempfile
import os
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Display python and library versions
# !python --versions
print('Numpy ' + np.__version__)
print('TensorFlow ' + tf.__version__)
print('Keras ' + tf.keras.__version__)
# Out:
# unknown option --versions
# usage: python3 [option] ... [-c cmd | -m mod | file | -] [arg] ...
# Try `python -h' for more information.
# Numpy 1.21.6
# TensorFlow 2.8.2
# Keras 2.8.0

# %% [markdown]
# # **Dataset Management**

# %%
# Loads the data and splits it into 60% training and 40% testing sets
df = loadtxt("drive/MyDrive/GE_practicum/diabetes.csv", delimiter=",", skiprows=1)

x_train = df[0:int(0.6*len(df)),0:8]
y_train = df[0:int(0.6*len(df)),8]

x_test = df[int(0.6*len(df)):,0:8]
y_test = df[int(0.6*len(df)):,8]

# %% [markdown]
# # **Model Training**

# %%
# Generates, compiles and trains model architecture without quantization aware training
model = Sequential()

model.add(Dense(128, input_dim=8, activation = 'relu'))
model.add(Dense(64,activation = 'relu'))
model.add(Dense(32,activation = 'relu'))
model.add(Dense(1,activation = 'sigmoid'))

opt = tf.keras.optimizers.Adam(lr = 1e-3,decay = 1e-5)
model.compile(optimizer = opt,loss = "binary_crossentropy" , metrics=['accuracy'])
model.fit(x_train,y_train,epochs = 50,validation_data = (x_test,y_test), batch_size=10)

model.save('ANN_base')
# Out:
# Epoch 1/50
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 46/46 [==============================] - 1s 6ms/step - loss: 1.5086 - accuracy: 0.5717 - val_loss: 0.6267 - val_accuracy: 0.6916
# Epoch 2/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6931 - accuracy: 0.6696 - val_loss: 0.6809 - val_accuracy: 0.6656
# Epoch 3/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.6540 - accuracy: 0.6565 - val_loss: 0.6154 - val_accuracy: 0.6721
# Epoch 4/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.6758 - accuracy: 0.6739 - val_loss: 0.7907 - val_accuracy: 0.5195
# Epoch 5/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.6641 - accuracy: 0.6543 - val_loss: 0.6532 - val_accuracy: 0.6201
# Epoch 6/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5987 - accuracy: 0.6913 - val_loss: 0.6308 - val_accuracy: 0.7305
# Epoch 7/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.6742 - accuracy: 0.6565 - val_loss: 0.6954 - val_accuracy: 0.5714
# Epoch 8/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.6467 - accuracy: 0.6630 - val_loss: 0.5786 - val_accuracy: 0.7175
# Epoch 9/50
# 46/46 [==============================] - 0s 6ms/step - loss: 0.6045 - accuracy: 0.6826 - val_loss: 0.6281 - val_accuracy: 0.6688
# Epoch 10/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5983 - accuracy: 0.6913 - val_loss: 0.6793 - val_accuracy: 0.6169
# Epoch 11/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.6458 - accuracy: 0.6652 - val_loss: 0.6603 - val_accuracy: 0.6429
# Epoch 12/50
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5827 - accuracy: 0.6935 - val_loss: 0.5679 - val_accuracy: 0.7013
# Epoch 13/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.6180 - accuracy: 0.6935 - val_loss: 0.6431 - val_accuracy: 0.6331
# Epoch 14/50
# 46/46 [==============================] - 0s 6ms/step - loss: 0.6046 - accuracy: 0.6761 - val_loss: 0.6254 - val_accuracy: 0.6656
# Epoch 15/50
# 46/46 [==============================] - 0s 8ms/step - loss: 0.5786 - accuracy: 0.6826 - val_loss: 0.6013 - val_accuracy: 0.7175
# Epoch 16/50
# 46/46 [==============================] - 0s 5ms/step - loss: 0.5711 - accuracy: 0.7043 - val_loss: 0.6001 - val_accuracy: 0.7045
# Epoch 17/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5427 - accuracy: 0.7283 - val_loss: 0.6112 - val_accuracy: 0.6786
# Epoch 18/50
# 46/46 [==============================] - 0s 8ms/step - loss: 0.5354 - accuracy: 0.7239 - val_loss: 0.6157 - val_accuracy: 0.6948
# Epoch 19/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5821 - accuracy: 0.7022 - val_loss: 0.6047 - val_accuracy: 0.6818
# Epoch 20/50
# 46/46 [==============================] - 0s 7ms/step - loss: 0.5620 - accuracy: 0.7087 - val_loss: 0.6708 - val_accuracy: 0.5844
# Epoch 21/50
# 46/46 [==============================] - 0s 6ms/step - loss: 0.5732 - accuracy: 0.7109 - val_loss: 0.7074 - val_accuracy: 0.6201
# Epoch 22/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5566 - accuracy: 0.7130 - val_loss: 0.5744 - val_accuracy: 0.7208
# Epoch 23/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5445 - accuracy: 0.6957 - val_loss: 0.5820 - val_accuracy: 0.7208
# Epoch 24/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5459 - accuracy: 0.7130 - val_loss: 0.6727 - val_accuracy: 0.6656
# Epoch 25/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5511 - accuracy: 0.7152 - val_loss: 0.6042 - val_accuracy: 0.6753
# Epoch 26/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5489 - accuracy: 0.7239 - val_loss: 0.6728 - val_accuracy: 0.5714
# Epoch 27/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5929 - accuracy: 0.6848 - val_loss: 0.6345 - val_accuracy: 0.6234
# Epoch 28/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5577 - accuracy: 0.6935 - val_loss: 0.6024 - val_accuracy: 0.7240
# Epoch 29/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5331 - accuracy: 0.7217 - val_loss: 0.6458 - val_accuracy: 0.6136
# Epoch 30/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5713 - accuracy: 0.6913 - val_loss: 0.5751 - val_accuracy: 0.7240
# Epoch 31/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5441 - accuracy: 0.6978 - val_loss: 0.5776 - val_accuracy: 0.7305
# Epoch 32/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5202 - accuracy: 0.7109 - val_loss: 0.5901 - val_accuracy: 0.7013
# Epoch 33/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5452 - accuracy: 0.7130 - val_loss: 0.6180 - val_accuracy: 0.7208
# Epoch 34/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5804 - accuracy: 0.7087 - val_loss: 0.5881 - val_accuracy: 0.7013
# Epoch 35/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5520 - accuracy: 0.6978 - val_loss: 0.5677 - val_accuracy: 0.7013
# Epoch 36/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5572 - accuracy: 0.7174 - val_loss: 0.5703 - val_accuracy: 0.7208
# Epoch 37/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5324 - accuracy: 0.7239 - val_loss: 0.6243 - val_accuracy: 0.6851
# Epoch 38/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5242 - accuracy: 0.7196 - val_loss: 0.5659 - val_accuracy: 0.7338
# Epoch 39/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5249 - accuracy: 0.7348 - val_loss: 0.6146 - val_accuracy: 0.6721
# Epoch 40/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5210 - accuracy: 0.7304 - val_loss: 0.6149 - val_accuracy: 0.6818
# Epoch 41/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5133 - accuracy: 0.7435 - val_loss: 0.6123 - val_accuracy: 0.6753
# Epoch 42/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5220 - accuracy: 0.7304 - val_loss: 0.6110 - val_accuracy: 0.6883
# Epoch 43/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5145 - accuracy: 0.7435 - val_loss: 0.6626 - val_accuracy: 0.6071
# Epoch 44/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5137 - accuracy: 0.7478 - val_loss: 0.5874 - val_accuracy: 0.7110
# Epoch 45/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5140 - accuracy: 0.7565 - val_loss: 0.6660 - val_accuracy: 0.6169
# Epoch 46/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5220 - accuracy: 0.7413 - val_loss: 0.5637 - val_accuracy: 0.7208
# Epoch 47/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5086 - accuracy: 0.7652 - val_loss: 0.5583 - val_accuracy: 0.7305
# Epoch 48/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.4939 - accuracy: 0.7522 - val_loss: 0.5909 - val_accuracy: 0.6981
# Epoch 49/50
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5002 - accuracy: 0.7435 - val_loss: 0.6258 - val_accuracy: 0.6786
# Epoch 50/50
# 46/46 [==============================] - 0s 4ms/step - loss: 0.5236 - accuracy: 0.7217 - val_loss: 0.6136 - val_accuracy: 0.7240
# INFO:tensorflow:Assets written to: ANN_base/assets

# %%
# !zip -r ANN_base.zip ANN_base
# Out:
# updating: ANN_base/ (stored 0%)
# updating: ANN_base/keras_metadata.pb (deflated 88%)
# updating: ANN_base/variables/ (stored 0%)
# updating: ANN_base/variables/variables.data-00000-of-00001 (deflated 25%)
# updating: ANN_base/variables/variables.index (deflated 64%)
# updating: ANN_base/saved_model.pb (deflated 88%)
# updating: ANN_base/assets/ (stored 0%)
